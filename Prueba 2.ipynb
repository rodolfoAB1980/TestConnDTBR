# %% [markdown]
# Prueba generacion archivo

# %%
# %sql
select *
from catalog_lhcl_prod_bcp_expl.bcp_edv_goblin.m_traslado_base;

# %%
import csv

# Define the data
rows = [["name", "age"], ["John", 25], ["Jane", 30], ["Bob", 35]]

# Define the path. Use a relative or absolute path; the 'file:' schema is required for some Spark operations.
# Pandas can handle relative paths directly.
file_path = "/Workspace/Users/rodolfoacunab@bcp.com.pe/TestConnGITRAB/people_open.csv"

# Write CSV using with open
with open(file_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerows(rows)

print(f"CSV file created at: {file_path}")
